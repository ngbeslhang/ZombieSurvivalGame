# %% [markdown]
# # Documentation
# Most of the documentation is included as a separate file/folder instead. This Jupyter notebook will only contain the entirety of the codebase needed to run the game, as well as explanation of each section of the code.
